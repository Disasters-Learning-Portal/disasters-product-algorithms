# %% [markdown]
# # 📝 Filename Renaming Template
#
# > **Dev/Testing Version:** This notebook uses Python imports from `shared_utils` for development testing. For production Hub deployment, use the CLI version in `notebooks/`.
#
# This notebook creates a mapping CSV of original filenames to new filenames without processing the files.
#
# ## 📊 Output CSV Columns
# - `original_s3_path` - Full S3 path to original file
# - `original_filename` - Original filename only
# - `new_filename` - Proposed new filename
# - `category` - File category
# - `file_size_gb` - File size in GB
# - `nodata_value` - Nodata value detected in the file
# - `status` - Validation status
# - `output_s3_path` - Proposed destination path
#
# ---

# %% [markdown]
# ## 📋 Step 1: Basic Configuration
#
# Set your event details and S3 paths:

# %%
# ========================================
# INPUTS
# ========================================

# S3 Paths (DO NOT CHANGE)
BUCKET = 'nasa-disasters'    # S3 bucket
DESTINATION_BASE = 'drcs_activations_new'  # Where to save COGs in S3 bucket
GEOTIFF_DIR = 'drcs_activations' # This is where all raw geotiff files currently are


# Event Details
EVENT_NAME = '202510_Flood_AK'  # Your event name
SUB_PRODUCT_NAME = 'sentinel2'         # Sub-directories within EVENT_NAME (RGB, trueColor, SWIR, etc.). Can leave blank.
SOURCE_PATH = f'{GEOTIFF_DIR}/{EVENT_NAME}/{SUB_PRODUCT_NAME}'      # Where your files are


# Output Options
SAVE_CSV = True          # Save mapping to CSV file
OUTPUT_DIR = 'file-mapping'    # Local directory for CSV output

print(f"Event: {EVENT_NAME}")
print(f"Source: s3://{BUCKET}/{SOURCE_PATH}")

import re
assert re.match(r'^\d{6}_\w+_\w+$', EVENT_NAME), \
    f"EVENT_NAME must follow format: YYYYMM_Text_Text, got: '{EVENT_NAME}'"
# Out:
# Event: 202510_Flood_AK
# Source: s3://nasa-disasters/drcs_activations/202510_Flood_AK/sentinel2

# %% [markdown]
# ## 🔍 Step 2: Connect to S3 and List Files
#
# Connect to S3 and view available files with their sizes:

# %%
# Import necessary modules
import sys
import os
import boto3
import pandas as pd
from pathlib import Path
from datetime import datetime

# Add parent directory to path for importing functions
sys.path.insert(0, str(Path('..').resolve()))
from shared_utils.s3_operations import list_s3_files, get_file_size_from_s3, initialize_s3_client

# Initialize S3 client
print("Connecting to S3...")
s3_client, _ = initialize_s3_client(bucket_name=BUCKET, verbose=False)


# List all TIF files
print(f"Files in s3://{BUCKET}/{SOURCE_PATH}:")
print("="*80)

files = list_s3_files(s3_client, BUCKET, SOURCE_PATH, suffix='.tif')

if files:
    print(f"Found {len(files)} .tif files\n")
    
    # Create initial DataFrame with file info
    file_data = []
    for file_path in files:
        filename = os.path.basename(file_path)
        try:
            size_gb = get_file_size_from_s3(s3_client, BUCKET, file_path)
        except:
            size_gb = 0.0
        
        file_data.append({
            'original_s3_path': file_path,
            'original_filename': filename,
            'file_size_gb': size_gb
        })
    
    files_df = pd.DataFrame(file_data)
    
    # Display summary
    print(f"Total files: {len(files)}")
    print(f"Total size: {files_df['file_size_gb'].sum():.2f} GB\n")
    
    # Display ALL files
    print(f"Complete file list:")
    print("-" * 80)
    for i, row in files_df.iterrows():
        print(f"{i+1:3}. {row['original_filename']:<65} ({row['file_size_gb']:.2f} GB)")
else:
    print("⚠️ No .tif files found in the specified path.")
    print("   Check your SOURCE_PATH configuration.")
    files_df = pd.DataFrame()
# Out:
# Connecting to S3...
# Files in s3://nasa-disasters/drcs_activations/202510_Flood_AK/sentinel2:
# ================================================================================
# Found 123 .tif files
#
# Total files: 123
# Total size: 31.09 GB
#
# Complete file list:
# --------------------------------------------------------------------------------
#   1. S2B_MSIL2A_colorInfrared_20250913_222529_T03VVG.tif               (0.34 GB)
#   2. S2B_MSIL2A_colorInfrared_20250913_222529_T03VVH.tif               (0.34 GB)
#   3. S2B_MSIL2A_colorInfrared_20250913_222529_T03VVJ.tif               (0.34 GB)
#   4. S2B_MSIL2A_colorInfrared_20250913_222529_T03VWG.tif               (0.34 GB)
#   5. S2B_MSIL2A_colorInfrared_20250913_222529_T03VWH.tif               (0.34 GB)
#   6. S2B_MSIL2A_colorInfrared_20250913_222529_T03VWJ.tif               (0.34 GB)
#   7. S2B_MSIL2A_colorInfrared_20250913_222529_T03VXG.tif               (0.34 GB)
#   8. S2B_MSIL2A_colorInfrared_20250913_222529_T03VXH.tif               (0.34 GB)
#   9. S2B_MSIL2A_colorInfrared_20250913_222529_T03VXJ.tif               (0.34 GB)
#  10. S2B_MSIL2A_colorInfrared_20250913_222529_T04VCM.tif               (0.34 GB)
#  11. S2B_MSIL2A_colorInfrared_20250913_222529_T04VCN.tif               (0.34 GB)
#  12. S2B_MSIL2A_colorInfrared_20250913_222529_T04VCP.tif               (0.34 GB)
#  13. S2B_MSIL2A_colorInfrared_20250913_222529_T04VDP.tif               (0.34 GB)
#  14. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVG.tif           (0.08 GB)
#  15. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVH.tif           (0.08 GB)
#  16. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVJ.tif           (0.08 GB)
#  17. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWG.tif           (0.08 GB)
#  18. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWH.tif           (0.08 GB)
#  19. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWJ.tif           (0.08 GB)
#  20. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXG.tif           (0.08 GB)
#  21. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXH.tif           (0.08 GB)
#  22. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXJ.tif           (0.08 GB)
#  23. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCM.tif           (0.08 GB)
#  24. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCN.tif           (0.08 GB)
#  25. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCP.tif           (0.08 GB)
#  26. S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VDP.tif           (0.08 GB)
#  27. S2B_MSIL2A_trueColor_20250913_222529_T03VVG.tif                   (0.34 GB)
#  28. S2B_MSIL2A_trueColor_20250913_222529_T03VVH.tif                   (0.34 GB)
#  29. S2B_MSIL2A_trueColor_20250913_222529_T03VVJ.tif                   (0.34 GB)
#  30. S2B_MSIL2A_trueColor_20250913_222529_T03VWG.tif                   (0.34 GB)
#  31. S2B_MSIL2A_trueColor_20250913_222529_T03VWH.tif                   (0.34 GB)
#  32. S2B_MSIL2A_trueColor_20250913_222529_T03VWJ.tif                   (0.34 GB)
#  33. S2B_MSIL2A_trueColor_20250913_222529_T03VXG.tif                   (0.34 GB)
#  34. S2B_MSIL2A_trueColor_20250913_222529_T03VXH.tif                   (0.34 GB)
#  35. S2B_MSIL2A_trueColor_20250913_222529_T03VXJ.tif                   (0.34 GB)
#  36. S2B_MSIL2A_trueColor_20250913_222529_T04VCM.tif                   (0.34 GB)
#  37. S2B_MSIL2A_trueColor_20250913_222529_T04VCN.tif                   (0.34 GB)
#  38. S2B_MSIL2A_trueColor_20250913_222529_T04VCP.tif                   (0.34 GB)
#  39. S2B_MSIL2A_trueColor_20250913_222529_T04VDP.tif                   (0.34 GB)
#  40. S2C_MSIL2A_colorInfrared_20251018_222541_T03VVG.tif               (0.34 GB)
#  41. S2C_MSIL2A_colorInfrared_20251018_222541_T03VVH.tif               (0.34 GB)
#  42. S2C_MSIL2A_colorInfrared_20251018_222541_T03VVJ.tif               (0.34 GB)
#  43. S2C_MSIL2A_colorInfrared_20251018_222541_T03VWG.tif               (0.34 GB)
#  44. S2C_MSIL2A_colorInfrared_20251018_222541_T03VWH.tif               (0.34 GB)
#  45. S2C_MSIL2A_colorInfrared_20251018_222541_T03VWJ.tif               (0.34 GB)
#  46. S2C_MSIL2A_colorInfrared_20251018_222541_T03VXG.tif               (0.34 GB)
#  47. S2C_MSIL2A_colorInfrared_20251018_222541_T03VXH.tif               (0.34 GB)
#  48. S2C_MSIL2A_colorInfrared_20251018_222541_T03VXJ.tif               (0.34 GB)
#  49. S2C_MSIL2A_colorInfrared_20251018_222541_T04VCM.tif               (0.34 GB)
#  50. S2C_MSIL2A_colorInfrared_20251018_222541_T04VCN.tif               (0.34 GB)
#  51. S2C_MSIL2A_colorInfrared_20251018_222541_T04VCP.tif               (0.34 GB)
#  52. S2C_MSIL2A_colorInfrared_20251018_222541_T04VDP.tif               (0.34 GB)
#  53. S2C_MSIL2A_colorInfrared_20251021_223601_T03VVG.tif               (0.34 GB)
#  54. S2C_MSIL2A_colorInfrared_20251021_223601_T03VVH.tif               (0.34 GB)
#  55. S2C_MSIL2A_colorInfrared_20251021_223601_T03VVJ.tif               (0.34 GB)
#  56. S2C_MSIL2A_colorInfrared_20251021_223601_T03VVK.tif               (0.34 GB)
#  57. S2C_MSIL2A_colorInfrared_20251021_223601_T03VVL.tif               (0.34 GB)
#  58. S2C_MSIL2A_colorInfrared_20251021_223601_T03VWG.tif               (0.34 GB)
#  59. S2C_MSIL2A_colorInfrared_20251021_223601_T03VWH.tif               (0.34 GB)
#  60. S2C_MSIL2A_colorInfrared_20251021_223601_T03VWJ.tif               (0.34 GB)
#  61. S2C_MSIL2A_colorInfrared_20251021_223601_T03VWK.tif               (0.34 GB)
#  62. S2C_MSIL2A_colorInfrared_20251021_223601_T03VWL.tif               (0.34 GB)
#  63. S2C_MSIL2A_colorInfrared_20251021_223601_T03VXJ.tif               (0.34 GB)
#  64. S2C_MSIL2A_colorInfrared_20251021_223601_T03VXK.tif               (0.34 GB)
#  65. S2C_MSIL2A_colorInfrared_20251021_223601_T03VXL.tif               (0.34 GB)
#  66. S2C_MSIL2A_colorInfrared_20251021_223601_T03WWQ.tif               (0.34 GB)
#  67. S2C_MSIL2A_colorInfrared_20251021_223601_T03WXQ.tif               (0.34 GB)
#  68. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVG.tif           (0.08 GB)
#  69. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVH.tif           (0.08 GB)
#  70. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVJ.tif           (0.08 GB)
#  71. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWG.tif           (0.08 GB)
#  72. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWH.tif           (0.08 GB)
#  73. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWJ.tif           (0.08 GB)
#  74. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXG.tif           (0.08 GB)
#  75. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXH.tif           (0.08 GB)
#  76. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXJ.tif           (0.08 GB)
#  77. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCM.tif           (0.08 GB)
#  78. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCN.tif           (0.08 GB)
#  79. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCP.tif           (0.08 GB)
#  80. S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VDP.tif           (0.08 GB)
#  81. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVG.tif           (0.08 GB)
#  82. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVH.tif           (0.08 GB)
#  83. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVJ.tif           (0.08 GB)
#  84. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVK.tif           (0.08 GB)
#  85. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVL.tif           (0.08 GB)
#  86. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWG.tif           (0.08 GB)
#  87. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWH.tif           (0.08 GB)
#  88. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWJ.tif           (0.08 GB)
#  89. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWK.tif           (0.08 GB)
#  90. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWL.tif           (0.08 GB)
#  91. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXJ.tif           (0.08 GB)
#  92. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXK.tif           (0.08 GB)
#  93. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXL.tif           (0.08 GB)
#  94. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03WWQ.tif           (0.08 GB)
#  95. S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03WXQ.tif           (0.08 GB)
#  96. S2C_MSIL2A_trueColor_20251018_222541_T03VVG.tif                   (0.34 GB)
#  97. S2C_MSIL2A_trueColor_20251018_222541_T03VVH.tif                   (0.34 GB)
#  98. S2C_MSIL2A_trueColor_20251018_222541_T03VVJ.tif                   (0.34 GB)
#  99. S2C_MSIL2A_trueColor_20251018_222541_T03VWG.tif                   (0.34 GB)
# 100. S2C_MSIL2A_trueColor_20251018_222541_T03VWH.tif                   (0.34 GB)
# 101. S2C_MSIL2A_trueColor_20251018_222541_T03VWJ.tif                   (0.34 GB)
# 102. S2C_MSIL2A_trueColor_20251018_222541_T03VXG.tif                   (0.34 GB)
# 103. S2C_MSIL2A_trueColor_20251018_222541_T03VXH.tif                   (0.34 GB)
# 104. S2C_MSIL2A_trueColor_20251018_222541_T03VXJ.tif                   (0.34 GB)
# 105. S2C_MSIL2A_trueColor_20251018_222541_T04VCM.tif                   (0.34 GB)
# 106. S2C_MSIL2A_trueColor_20251018_222541_T04VCN.tif                   (0.34 GB)
# 107. S2C_MSIL2A_trueColor_20251018_222541_T04VCP.tif                   (0.34 GB)
# 108. S2C_MSIL2A_trueColor_20251018_222541_T04VDP.tif                   (0.34 GB)
# 109. S2C_MSIL2A_trueColor_20251021_223601_T03VVG.tif                   (0.34 GB)
# 110. S2C_MSIL2A_trueColor_20251021_223601_T03VVH.tif                   (0.34 GB)
# 111. S2C_MSIL2A_trueColor_20251021_223601_T03VVJ.tif                   (0.34 GB)
# 112. S2C_MSIL2A_trueColor_20251021_223601_T03VVK.tif                   (0.34 GB)
# 113. S2C_MSIL2A_trueColor_20251021_223601_T03VVL.tif                   (0.34 GB)
# 114. S2C_MSIL2A_trueColor_20251021_223601_T03VWG.tif                   (0.34 GB)
# 115. S2C_MSIL2A_trueColor_20251021_223601_T03VWH.tif                   (0.34 GB)
# 116. S2C_MSIL2A_trueColor_20251021_223601_T03VWJ.tif                   (0.34 GB)
# 117. S2C_MSIL2A_trueColor_20251021_223601_T03VWK.tif                   (0.34 GB)
# 118. S2C_MSIL2A_trueColor_20251021_223601_T03VWL.tif                   (0.34 GB)
# 119. S2C_MSIL2A_trueColor_20251021_223601_T03VXJ.tif                   (0.34 GB)
# 120. S2C_MSIL2A_trueColor_20251021_223601_T03VXK.tif                   (0.34 GB)
# 121. S2C_MSIL2A_trueColor_20251021_223601_T03VXL.tif                   (0.34 GB)
# 122. S2C_MSIL2A_trueColor_20251021_223601_T03WWQ.tif                   (0.34 GB)
# 123. S2C_MSIL2A_trueColor_20251021_223601_T03WXQ.tif                   (0.34 GB)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 57
#      55     print("   Check your SOURCE_PATH configuration.")
#      56     files_df = pd.DataFrame()
# ---> 57 g
#
# NameError: name 'g' is not defined

# %% [markdown]
# ## 🏷️ Step 3: Define Filename Transformation Functions
#
# Based on the files you see above, configure:
# 1. **Categorization patterns** - Regex patterns to identify file types
# 2. **Filename functions** - How to transform filenames
# 3. **Output directories** - Where each category should be saved

# %%
# ========================================
# CATEGORIZATION AND FILENAME TRANSFORMATION
# ========================================

#Define helper function to extract dates from filenames
def extract_date_from_filename(filename):
    """Extract date from filename in YYYY-MM-DD format."""
    # Try YYYYMMDD format (d{8} finds a sequence of 8 digits from filename)
    dates = re.findall(r'\d{8}', filename)
    if dates:
        date_str = dates[0]
        # Then it splits the date into different sections
        return f"{date_str[0:4]}-{date_str[4:6]}-{date_str[6:8]}"
    
    # Try YYYY-MM-DD format
    dates = re.findall(r'\d{4}-\d{2}-\d{2}', filename)
    if dates:
        return dates[0]
    
    return None

#Define filename transformation functions for each category
def create_TC_SWIR_NC_CIR_filename(original_path, event_name):
    """Create filename for trueColor products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_?\d{8}', '', stem)
        stem_clean = re.sub(r'_?\d{4}-\d{2}-\d{2}', '', stem_clean)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"

# %% [markdown]
# # Test new function with filename

# %%
# Now test a function with a filename to verify it's valid
oldName='S2B_MSIL2A_colorInfrared_20250913_222529_T03VVG'
print(f'Old name: {oldName}')
print(f'New name: {create_TC_SWIR_NC_CIR_filename(oldName, EVENT_NAME)}')
# Out:
# Old name: S2B_MSIL2A_colorInfrared_20250913_222529_T03VVG
# New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVG_2025-09-13_day.tif

# %%
# Configure categorization patterns (REQUIRED)
# These regex patterns determine which files belong to which category
CATEGORIZATION_PATTERNS = {
    'trueColor': r'trueColor|truecolor|true_color',
    'colorInfrared': r'colorInfrared|colorIR|color_infrared',
    'naturalColor': r'naturalColor|naturalcolor|natural_color',
    'shortwaveIR': r'shortwaveIR|shortwaveinfrared|shortwaveInfrared'
    # Add patterns for ALL file types you want to process
    # Files not matching any pattern will be marked as 'uncategorized'
}

# Map categories to filename transformation functions
FILENAME_CREATORS = {
    'trueColor': create_TC_SWIR_NC_CIR_filename,
    'colorInfrared': create_TC_SWIR_NC_CIR_filename,
    'naturalColor': create_TC_SWIR_NC_CIR_filename,
    'shortwaveIR': create_TC_SWIR_NC_CIR_filename
    # Must have an entry for each category in CATEGORIZATION_PATTERNS
}

# Specify output directories for each category
OUTPUT_DIRS = {
    'trueColor': 'Sentinel-2/trueColor',
    'colorInfrared': 'Sentinel-2/colorIR',
    'naturalColor': 'Sentinel-2/naturalColor',
    'shortwaveIR': 'Sentinel-2/shortwaveIR'
    # Must have an entry for each category in CATEGORIZATION_PATTERNS
}

# Specify nodata values for each category
NODATA_VALUES = {
    'trueColor': 0,
    'colorInfrared': 0,
    'naturalColor': 0,
    'shortwaveIR': 0
    # Must have an entry for each category in CATEGORIZATION_PATTERNS
}

print("Filename transformation functions defined")
print(f"\nCategories configured: {len(CATEGORIZATION_PATTERNS)}")
for category in CATEGORIZATION_PATTERNS.keys():
    print(f"   • {category}")
# Out:
# Filename transformation functions defined
#
# Categories configured: 4
#    • trueColor
#    • colorInfrared
#    • naturalColor
#    • shortwaveIR

# %% [markdown]
# ## 🔍 Step 4: Preview Transformations
#
# Apply the transformation functions and preview the mapping:

# %%
if not files_df.empty:
    print("Applying filename transformations...\n")
    
    # Apply categorization and transformation
    def categorize_file(filename):
        """Categorize a file based on patterns."""
        for category, pattern in CATEGORIZATION_PATTERNS.items():
            if re.search(pattern, filename, re.IGNORECASE):
                return category
        return 'uncategorized'
    
    def transform_filename(row):
        """Transform filename based on category."""
        category = row['category']
        original_path = row['original_s3_path']
        
        if category == 'uncategorized':
            return os.path.basename(original_path)  # Keep original
        
        if category in FILENAME_CREATORS:
            return FILENAME_CREATORS[category](original_path, EVENT_NAME)
        
        return os.path.basename(original_path)
    
    def get_output_path(row):
        """Generate output S3 path."""
        category = row['category']
        new_filename = row['new_filename']
        
        if category == 'uncategorized':
            return f"{DESTINATION_BASE}/uncategorized/{new_filename}"
        
        if category in OUTPUT_DIRS:
            return f"{DESTINATION_BASE}/{OUTPUT_DIRS[category]}/{new_filename}"
        
        return f"{DESTINATION_BASE}/{category}/{new_filename}"
    
    def get_nodata_value(category):
        """Get nodata value for category."""
        if category in NODATA_VALUES:
            return NODATA_VALUES[category]
        return None  # Default for uncategorized
    
    # Apply transformations
    files_df['category'] = files_df['original_filename'].apply(categorize_file)
    files_df['new_filename'] = files_df.apply(transform_filename, axis=1)
    files_df['output_s3_path'] = files_df.apply(get_output_path, axis=1)
    files_df['nodata_value'] = files_df['category'].apply(get_nodata_value)
    files_df['status'] = 'valid'
    
    # Check for uncategorized files
    uncategorized = files_df[files_df['category'] == 'uncategorized']
    if not uncategorized.empty:
        files_df.loc[files_df['category'] == 'uncategorized', 'status'] = 'uncategorized'
    
    # Display preview
    print("TRANSFORMATION PREVIEW")
    print("="*80)
    print(f"\nTotal files: {len(files_df)}")
    print(f"Categorized: {len(files_df[files_df['category'] != 'uncategorized'])}")
    print(f"Uncategorized: {len(uncategorized)}")
    
    # Show category breakdown
    print("\nFiles by category:")
    category_counts = files_df['category'].value_counts()
    for category, count in category_counts.items():
        nodata = NODATA_VALUES.get(category, 'None')
        print(f"   • {category}: {count} files (nodata={nodata})")
    
    # Show sample transformations
    print("\nTransformation information:")
    print("-" * 80)
    for i, row in files_df.iterrows():
        print(f"\n{i+1}. Original: {row['original_filename']}")
        print(f"   Category: {row['category']}")
        print(f"   New name: {row['new_filename']}")
        print(f"   Nodata:   {row['nodata_value']}")
        print(f"   Output:   s3://{BUCKET}/{row['output_s3_path']}")
    
    if len(uncategorized) > 0:
        print("\n⚠️  UNCATEGORIZED FILES:")
        print("-" * 80)
        for i, row in uncategorized.iterrows():
            print(f"   • {row['original_filename']}")
        print("\nAdd patterns to CATEGORIZATION_PATTERNS to categorize these files")
    
    print("\n" + "="*80)
else:
    print("⚠️ No files to process. Check Step 2.")
# Out:
# Applying filename transformations...
#
# TRANSFORMATION PREVIEW
# ================================================================================
#
# Total files: 123
# Categorized: 123
# Uncategorized: 0
#
# Files by category:
#    • colorInfrared: 41 files (nodata=0)
#    • shortwaveIR: 41 files (nodata=0)
#    • trueColor: 41 files (nodata=0)
#
# Transformation information:
# --------------------------------------------------------------------------------
#
# 1. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VVG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVG_2025-09-13_day.tif
#
# 2. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VVH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVH_2025-09-13_day.tif
#
# 3. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VVJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VVJ_2025-09-13_day.tif
#
# 4. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VWG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWG_2025-09-13_day.tif
#
# 5. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VWH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWH_2025-09-13_day.tif
#
# 6. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VWJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VWJ_2025-09-13_day.tif
#
# 7. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VXG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXG_2025-09-13_day.tif
#
# 8. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VXH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXH_2025-09-13_day.tif
#
# 9. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T03VXJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T03VXJ_2025-09-13_day.tif
#
# 10. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T04VCM.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCM_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCM_2025-09-13_day.tif
#
# 11. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T04VCN.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCN_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCN_2025-09-13_day.tif
#
# 12. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T04VCP.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VCP_2025-09-13_day.tif
#
# 13. Original: S2B_MSIL2A_colorInfrared_20250913_222529_T04VDP.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VDP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2B_MSIL2A_colorInfrared_222529_T04VDP_2025-09-13_day.tif
#
# 14. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVG_2025-09-13_day.tif
#
# 15. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVH_2025-09-13_day.tif
#
# 16. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VVJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VVJ_2025-09-13_day.tif
#
# 17. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWG_2025-09-13_day.tif
#
# 18. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWH_2025-09-13_day.tif
#
# 19. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VWJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VWJ_2025-09-13_day.tif
#
# 20. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXG_2025-09-13_day.tif
#
# 21. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXH_2025-09-13_day.tif
#
# 22. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T03VXJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T03VXJ_2025-09-13_day.tif
#
# 23. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCM.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCM_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCM_2025-09-13_day.tif
#
# 24. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCN.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCN_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCN_2025-09-13_day.tif
#
# 25. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VCP.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VCP_2025-09-13_day.tif
#
# 26. Original: S2B_MSIL2A_shortwaveInfrared_20250913_222529_T04VDP.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VDP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2B_MSIL2A_shortwaveInfrared_222529_T04VDP_2025-09-13_day.tif
#
# 27. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VVG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVG_2025-09-13_day.tif
#
# 28. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VVH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVH_2025-09-13_day.tif
#
# 29. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VVJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VVJ_2025-09-13_day.tif
#
# 30. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VWG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWG_2025-09-13_day.tif
#
# 31. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VWH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWH_2025-09-13_day.tif
#
# 32. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VWJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VWJ_2025-09-13_day.tif
#
# 33. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VXG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXG_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXG_2025-09-13_day.tif
#
# 34. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VXH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXH_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXH_2025-09-13_day.tif
#
# 35. Original: S2B_MSIL2A_trueColor_20250913_222529_T03VXJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXJ_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T03VXJ_2025-09-13_day.tif
#
# 36. Original: S2B_MSIL2A_trueColor_20250913_222529_T04VCM.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCM_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCM_2025-09-13_day.tif
#
# 37. Original: S2B_MSIL2A_trueColor_20250913_222529_T04VCN.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCN_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCN_2025-09-13_day.tif
#
# 38. Original: S2B_MSIL2A_trueColor_20250913_222529_T04VCP.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VCP_2025-09-13_day.tif
#
# 39. Original: S2B_MSIL2A_trueColor_20250913_222529_T04VDP.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VDP_2025-09-13_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2B_MSIL2A_trueColor_222529_T04VDP_2025-09-13_day.tif
#
# 40. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VVG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVG_2025-10-18_day.tif
#
# 41. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VVH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVH_2025-10-18_day.tif
#
# 42. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VVJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VVJ_2025-10-18_day.tif
#
# 43. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VWG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWG_2025-10-18_day.tif
#
# 44. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VWH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWH_2025-10-18_day.tif
#
# 45. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VWJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VWJ_2025-10-18_day.tif
#
# 46. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VXG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXG_2025-10-18_day.tif
#
# 47. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VXH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXH_2025-10-18_day.tif
#
# 48. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T03VXJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T03VXJ_2025-10-18_day.tif
#
# 49. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T04VCM.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCM_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCM_2025-10-18_day.tif
#
# 50. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T04VCN.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCN_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCN_2025-10-18_day.tif
#
# 51. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T04VCP.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VCP_2025-10-18_day.tif
#
# 52. Original: S2C_MSIL2A_colorInfrared_20251018_222541_T04VDP.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VDP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_222541_T04VDP_2025-10-18_day.tif
#
# 53. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VVG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVG_2025-10-21_day.tif
#
# 54. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VVH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVH_2025-10-21_day.tif
#
# 55. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VVJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVJ_2025-10-21_day.tif
#
# 56. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VVK.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVK_2025-10-21_day.tif
#
# 57. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VVL.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VVL_2025-10-21_day.tif
#
# 58. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VWG.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWG_2025-10-21_day.tif
#
# 59. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VWH.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWH_2025-10-21_day.tif
#
# 60. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VWJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWJ_2025-10-21_day.tif
#
# 61. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VWK.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWK_2025-10-21_day.tif
#
# 62. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VWL.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VWL_2025-10-21_day.tif
#
# 63. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VXJ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXJ_2025-10-21_day.tif
#
# 64. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VXK.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXK_2025-10-21_day.tif
#
# 65. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03VXL.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03VXL_2025-10-21_day.tif
#
# 66. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03WWQ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03WWQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03WWQ_2025-10-21_day.tif
#
# 67. Original: S2C_MSIL2A_colorInfrared_20251021_223601_T03WXQ.tif
#    Category: colorInfrared
#    New name: 202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03WXQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/colorIR/202510_Flood_AK_S2C_MSIL2A_colorInfrared_223601_T03WXQ_2025-10-21_day.tif
#
# 68. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVG_2025-10-18_day.tif
#
# 69. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVH_2025-10-18_day.tif
#
# 70. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VVJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VVJ_2025-10-18_day.tif
#
# 71. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWG_2025-10-18_day.tif
#
# 72. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWH_2025-10-18_day.tif
#
# 73. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VWJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VWJ_2025-10-18_day.tif
#
# 74. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXG_2025-10-18_day.tif
#
# 75. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXH_2025-10-18_day.tif
#
# 76. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T03VXJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T03VXJ_2025-10-18_day.tif
#
# 77. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCM.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCM_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCM_2025-10-18_day.tif
#
# 78. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCN.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCN_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCN_2025-10-18_day.tif
#
# 79. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VCP.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VCP_2025-10-18_day.tif
#
# 80. Original: S2C_MSIL2A_shortwaveInfrared_20251018_222541_T04VDP.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VDP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_222541_T04VDP_2025-10-18_day.tif
#
# 81. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVG_2025-10-21_day.tif
#
# 82. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVH_2025-10-21_day.tif
#
# 83. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVJ_2025-10-21_day.tif
#
# 84. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVK.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVK_2025-10-21_day.tif
#
# 85. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VVL.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VVL_2025-10-21_day.tif
#
# 86. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWG.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWG_2025-10-21_day.tif
#
# 87. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWH.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWH_2025-10-21_day.tif
#
# 88. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWJ_2025-10-21_day.tif
#
# 89. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWK.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWK_2025-10-21_day.tif
#
# 90. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VWL.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VWL_2025-10-21_day.tif
#
# 91. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXJ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXJ_2025-10-21_day.tif
#
# 92. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXK.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXK_2025-10-21_day.tif
#
# 93. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03VXL.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03VXL_2025-10-21_day.tif
#
# 94. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03WWQ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03WWQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03WWQ_2025-10-21_day.tif
#
# 95. Original: S2C_MSIL2A_shortwaveInfrared_20251021_223601_T03WXQ.tif
#    Category: shortwaveIR
#    New name: 202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03WXQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/shortwaveIR/202510_Flood_AK_S2C_MSIL2A_shortwaveInfrared_223601_T03WXQ_2025-10-21_day.tif
#
# 96. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VVG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVG_2025-10-18_day.tif
#
# 97. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VVH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVH_2025-10-18_day.tif
#
# 98. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VVJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VVJ_2025-10-18_day.tif
#
# 99. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VWG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWG_2025-10-18_day.tif
#
# 100. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VWH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWH_2025-10-18_day.tif
#
# 101. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VWJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VWJ_2025-10-18_day.tif
#
# 102. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VXG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXG_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXG_2025-10-18_day.tif
#
# 103. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VXH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXH_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXH_2025-10-18_day.tif
#
# 104. Original: S2C_MSIL2A_trueColor_20251018_222541_T03VXJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXJ_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T03VXJ_2025-10-18_day.tif
#
# 105. Original: S2C_MSIL2A_trueColor_20251018_222541_T04VCM.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCM_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCM_2025-10-18_day.tif
#
# 106. Original: S2C_MSIL2A_trueColor_20251018_222541_T04VCN.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCN_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCN_2025-10-18_day.tif
#
# 107. Original: S2C_MSIL2A_trueColor_20251018_222541_T04VCP.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VCP_2025-10-18_day.tif
#
# 108. Original: S2C_MSIL2A_trueColor_20251018_222541_T04VDP.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VDP_2025-10-18_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_222541_T04VDP_2025-10-18_day.tif
#
# 109. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VVG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVG_2025-10-21_day.tif
#
# 110. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VVH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVH_2025-10-21_day.tif
#
# 111. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VVJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVJ_2025-10-21_day.tif
#
# 112. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VVK.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVK_2025-10-21_day.tif
#
# 113. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VVL.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VVL_2025-10-21_day.tif
#
# 114. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VWG.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWG_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWG_2025-10-21_day.tif
#
# 115. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VWH.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWH_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWH_2025-10-21_day.tif
#
# 116. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VWJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWJ_2025-10-21_day.tif
#
# 117. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VWK.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWK_2025-10-21_day.tif
#
# 118. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VWL.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VWL_2025-10-21_day.tif
#
# 119. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VXJ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXJ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXJ_2025-10-21_day.tif
#
# 120. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VXK.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXK_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXK_2025-10-21_day.tif
#
# 121. Original: S2C_MSIL2A_trueColor_20251021_223601_T03VXL.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXL_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03VXL_2025-10-21_day.tif
#
# 122. Original: S2C_MSIL2A_trueColor_20251021_223601_T03WWQ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03WWQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03WWQ_2025-10-21_day.tif
#
# 123. Original: S2C_MSIL2A_trueColor_20251021_223601_T03WXQ.tif
#    Category: trueColor
#    New name: 202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03WXQ_2025-10-21_day.tif
#    Nodata:   0
#    Output:   s3://nasa-disasters/drcs_activations_new/Sentinel-2/trueColor/202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T03WXQ_2025-10-21_day.tif
#
# ================================================================================

# %% [markdown]
# ## 💾 Step 5: Export Mapping to CSV
#
# Save the filename mapping to a CSV file:

# %%
if not files_df.empty and SAVE_CSV:
    # Create output directory
    output_path = Path(OUTPUT_DIR) / EVENT_NAME
    output_path.mkdir(parents=True, exist_ok=True)

    csv_filename = f"{EVENT_NAME}-{SUB_PRODUCT_NAME}.csv"
    csv_path = output_path / csv_filename
    
    # Reorder columns for better readability
    column_order = [
        'original_filename',
        'new_filename',
        'category',
        'file_size_gb',
        'nodata_value',
        'status',
        'original_s3_path',
        'output_s3_path'
    ]
    
    # Save to CSV
    files_df[column_order].to_csv(csv_path, index=False)
    
    print(f"EXPORT COMPLETE. Saved mapping to: {csv_path}")
    print("="*80)
    print(f"   Total records: {len(files_df)}")
    print(f"   Total size:    {files_df['file_size_gb'].sum():.2f} GB")
    print(f"   Valid:         {len(files_df[files_df['status'] == 'valid'])}")
    print(f"   Uncategorized: {len(files_df[files_df['status'] == 'uncategorized'])}")
    
    # Show nodata value distribution
    nodata_counts = files_df['nodata_value'].value_counts()
    print(f"\n   Nodata values:")
    for nodata, count in nodata_counts.items():
        print(f"      {nodata}: {count} files")
    
    print("\nYou can now use this CSV in a separate script to perform actual file renaming/copying")
    
    # Display the DataFrame
    print("\nFull mapping table:")
    print("="*80)
    display(files_df[column_order])
    
elif files_df.empty:
    print("⚠️ No files to export. Check previous steps.")
else:
    print("ℹ️  CSV export disabled (SAVE_CSV = False)")
# Out:
# EXPORT COMPLETE. Saved mapping to: file-mapping/202510_Flood_AK/202510_Flood_AK-sentinel2.csv
# ================================================================================
#    Total records: 123
#    Total size:    31.09 GB
#    Valid:         123
#    Uncategorized: 0
#
#    Nodata values:
#       0: 123 files
#
# You can now use this CSV in a separate script to perform actual file renaming/copying
#
# Full mapping table:
# ================================================================================
#                                      original_filename  \
# 0    S2B_MSIL2A_colorInfrared_20250913_222529_T03VV...
# 1    S2B_MSIL2A_colorInfrared_20250913_222529_T03VV...
# 2    S2B_MSIL2A_colorInfrared_20250913_222529_T03VV...
# 3    S2B_MSIL2A_colorInfrared_20250913_222529_T03VW...
# 4    S2B_MSIL2A_colorInfrared_20250913_222529_T03VW...
# ..                                                 ...
# 118    S2C_MSIL2A_trueColor_20251021_223601_T03VXJ.tif
# 119    S2C_MSIL2A_trueColor_20251021_223601_T03VXK.tif
# 120    S2C_MSIL2A_trueColor_20251021_223601_T03VXL.tif
# 121    S2C_MSIL2A_trueColor_20251021_223601_T03WWQ.tif
# 122    S2C_MSIL2A_trueColor_20251021_223601_T03WXQ.tif
#
#                                           new_filename       category  \
# 0    202510_Flood_AK_S2B_MSIL2A_colorInfrared_22252...  colorInfrared
# 1    202510_Flood_AK_S2B_MSIL2A_colorInfrared_22252...  colorInfrared
# 2    202510_Flood_AK_S2B_MSIL2A_colorInfrared_22252...  colorInfrared
# 3    202510_Flood_AK_S2B_MSIL2A_colorInfrared_22252...  colorInfrared
# 4    202510_Flood_AK_S2B_MSIL2A_colorInfrared_22252...  colorInfrared
# ..                                                 ...            ...
# 118  202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T0...      trueColor
# 119  202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T0...      trueColor
# 120  202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T0...      trueColor
# 121  202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T0...      trueColor
# 122  202510_Flood_AK_S2C_MSIL2A_trueColor_223601_T0...      trueColor
#
#      file_size_gb  nodata_value status  \
# 0        0.336965             0  valid
# 1        0.336965             0  valid
# 2        0.336965             0  valid
# 3        0.336965             0  valid
# 4        0.336965             0  valid
# ..            ...           ...    ...
# 118      0.336965             0  valid
# 119      0.336965             0  valid
# 120      0.336965             0  valid
# 121      0.336965             0  valid
# 122      0.336965             0  valid
#
#                                       original_s3_path  \
# 0    drcs_activations/202510_Flood_AK/sentinel2/S2B...
# 1    drcs_activations/202510_Flood_AK/sentinel2/S2B...
# 2    drcs_activations/202510_Flood_AK/sentinel2/S2B...
# 3    drcs_activations/202510_Flood_AK/sentinel2/S2B...
# 4    drcs_activations/202510_Flood_AK/sentinel2/S2B...
# ..                                                 ...
# 118  drcs_activations/202510_Flood_AK/sentinel2/S2C...
# 119  drcs_activations/202510_Flood_AK/sentinel2/S2C...
# 120  drcs_activations/202510_Flood_AK/sentinel2/S2C...
# 121  drcs_activations/202510_Flood_AK/sentinel2/S2C...
# 122  drcs_activations/202510_Flood_AK/sentinel2/S2C...
#
#                                         output_s3_path
# 0    drcs_activations_new/Sentinel-2/colorIR/202510...
# 1    drcs_activations_new/Sentinel-2/colorIR/202510...
# 2    drcs_activations_new/Sentinel-2/colorIR/202510...
# 3    drcs_activations_new/Sentinel-2/colorIR/202510...
# 4    drcs_activations_new/Sentinel-2/colorIR/202510...
# ..                                                 ...
# 118  drcs_activations_new/Sentinel-2/trueColor/2025...
# 119  drcs_activations_new/Sentinel-2/trueColor/2025...
# 120  drcs_activations_new/Sentinel-2/trueColor/2025...
# 121  drcs_activations_new/Sentinel-2/trueColor/2025...
# 122  drcs_activations_new/Sentinel-2/trueColor/2025...
#
# [123 rows x 8 columns]
